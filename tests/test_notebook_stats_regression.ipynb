# %%
import numpy as np
from pyrootmemo.stats import LinearRegression, PowerRegression
from pyrootmemo.helpers import Parameter
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
xn = np.linspace(1.0, 10.0, 30)
yn = 10.0 * xn**(-0.5) + 5 * np.random.rand(len(xn))
x = Parameter(xn, 'mm')
y = Parameter(yn, 'MPa')

# %%
fit = PowerRegression(x, y, model = 'gamma')
print(fit.multiplier)
print(fit.exponent)
print(fit.shape)
print(fit.calc_ks())
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 12.819384660986618 megapascal
# -0.3391575694360382
# 21.971395079662976
# 0.12455980170239778
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'gumbel')
print(fit.multiplier)
print(fit.exponent)
print(fit.scale0)
print(fit.calc_ks())
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 13.953608229951104 megapascal
# -0.3863893633954647
# 2.7994141850836343 megapascal
# 0.1544288349138329
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'logistic')
print(fit.multiplier)
print(fit.exponent)
print(fit.scale0)
print(fit.calc_ks())
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 12.331673409096501 megapascal
# -0.3027258408841549
# 1.40711795109415 megapascal
# 0.12638442211859194
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'weibull')
print(fit.zero_variance)
print(fit.multiplier)
print(fit.exponent)
print(fit.shape)
print(fit.calc_ks())
print(fit.calc_covariance_matrix())
print(fit.calc_quantile(fit.x, 0.95))
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# False
# 11.734190358507929 megapascal
# -0.278766070888544
# 6.304628165551601
# 0.13090036092920776
# [[ 0.8386907  -0.03893414  0.08462705]
#  [-0.03893414  0.00222194  0.00629878]
#  [ 0.08462705  0.00629878  0.94543307]]
# [15.01191818556249 13.922366645637364 13.121363981240735 12.495902425347724 11.987383500781304 11.561781316381397 11.197711479652957 10.88092247734263 10.601476100740378 10.352187152885897 10.127705436458433 9.923948207096867 9.737734643763547 9.566542190616325 9.408339301369939 9.261467683396525 9.124557539085963 8.99646535924319 8.876227472849179 8.76302482298437 8.656155882712142 8.555015567120863 8.459078625965452 8.367886428277512 8.281036345540196 8.198173147452575 8.118981972190392 8.043182539923686 7.970524356521763 7.900782712221801] megapascal
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'normal')
print(fit.multiplier)
print(fit.exponent)
print(fit.sd_multiplier)
print(fit.sd_exponent)
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 12.845673986812063 megapascal
# -0.34063361099255957
# 1.3971476676695336 megapascal
# 0.0
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'normal_force')
print(fit.multiplier)
print(fit.exponent)
print(fit.sd_multiplier)
print(fit.sd_exponent)
print(fit.calc_ks())
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 13.981080772417293 megapascal
# -0.3820875857610129
# 69.3663244241637 megapascal
# -2.0
# 0.17436946177946516
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'normal_freesd')
print(fit.multiplier)
print(fit.exponent)
print(fit.sd_multiplier)
print(fit.sd_exponent)
print(fit.calc_ks())
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 12.887270110230368 megapascal
# -0.34421033003804646
# 0.42100204005244335 megapascal
# 0.7154148217761053
# 0.1281368582164487
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'normal_scaled')
print(fit.multiplier)
print(fit.exponent)
print(fit.sd_multiplier)
print(fit.sd_exponent)
print(fit.calc_ks())
fit.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 12.218586270088531 megapascal
# -0.30794837213343523
# 2.459222135594397 megapascal
# -0.30794837213343523
# 0.12495677132627905
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'uniform')
print(fit.multiplier)
print(fit.exponent)
print(fit.width)
print(fit.calc_ks())
fit.plot(show_confidence = False, show_prediction = True, show_legend = True)
# Out:
# 9.923455762369663 megapascal
# -0.2286023182782726
# 7.22532727444653 megapascal
# 0.2558398508196982
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit = PowerRegression(x, y, model = 'uniform', algorithm = 'root')
print(fit.multiplier)
print(fit.exponent)
print(fit.width)
print(fit.calc_ks())
fit.plot(show_confidence = False, show_prediction = True, show_legend = True)
# Out:
# 9.92345576235411 megapascal
# -0.22860231827716815
# 7.22532727444032 megapascal
# 0.255839850820882
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)

# %%
fit_lm = LinearRegression(x, y)
print(fit_lm.intercept)
print(fit_lm.gradient)
fit_lm.plot(show_confidence = True, show_prediction = True, show_legend = True)
# Out:
# 11.149007851190834 megapascal
# -0.6136351265298703 megapascal / millimeter
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='x [mm]', ylabel='y [MPa]'>)
