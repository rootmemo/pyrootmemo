# %%
import numpy as np
from pyrootmemo.fit import GammaFit, GumbelFit, WeibullFit, PowerFit
from pyrootmemo.helpers import units

# %%
n = 100
xn = 2 + 8 * np.random.rand(n) 
x = xn * units('m')

# %%
fit = GammaFit(x)
print(fit.scale)
print(fit.shape)
print(fit.calc_density(8 * units('m')))
print(fit.calc_loglikelihood(deriv = 0))
print(fit.calc_loglikelihood(deriv = 1))
print(fit.calc_loglikelihood(deriv = 2))
fit.plot()
# Out:
# 0.8775018274921819 meter
# 6.969907329052232
# 0.0987781058791475 / meter
# -634.833392657804
# [-128.13488863 -585.7703026 ]
# [[ -26.80171752 -198.00264433]
#  [-198.00264433 -237.6285384 ]]
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: xlabel='x [m]', ylabel='Probability density [1 / m]'>)

# %%
fit = GumbelFit(x)
print(fit.scale)
print(fit.location)
print(fit.calc_density(8 * units('m')))
print(fit.calc_loglikelihood(deriv = 0))
print(fit.calc_loglikelihood(deriv = 1))
print(fit.calc_loglikelihood(deriv = 2))
fit.plot()
# Out:
# 1.9803139790038706 meter
# 5.028767321620809 meter
# 0.09011358038755937 / meter
# -223.23294979637762
# [-7.10542736e-15 -3.55271368e-15]
# [[-25.49951344  11.49839129]
#  [ 11.49839129 -48.1733638 ]]
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: xlabel='x [m]', ylabel='Probability density [1 / m]'>)

# %%
fit = WeibullFit(x)
print(fit.shape)
print(fit.scale)
print(fit.calc_density(8 * units('m')))
print(fit.calc_loglikelihood(deriv = 0))
print(fit.calc_loglikelihood(deriv = 1))
print(fit.calc_loglikelihood(deriv = 2))
fit.plot()
# Out:
# 3.1095866865223685
# 6.858914895341624 meter
# 0.12491406617981694 / meter
# 83014.09728990418
# [3.95363302e+04 1.45795656e+01]
# [[-32.7746398   19.73319396]
#  [ 19.73319396 -44.4474379 ]]
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: xlabel='x [m]', ylabel='Probability density [1 / m]'>)

# %%
fit = PowerFit(x)
print(fit.x0)
print(fit.multiplier)
print(fit.exponent)
print(fit.lower)
print(fit.upper)
xx = np.array([8]) * units('m')
print(fit.calc_density(xx))
print(fit.calc_density(xx, cumulative = True))
print(fit.calc_loglikelihood(deriv = 0))
print(fit.calc_loglikelihood(deriv = 1))
print(fit.calc_loglikelihood(deriv = 2))
fit.plot()
# Out:
# 1.0 meter
# 0.09107258305218656 / meter
# 0.2072981814264685
# 2.101605315412862 meter
# 9.78900121901587 meter
# [0.1401511179684606] / meter
# [0.7437706669985841] dimensionless
# -203.59226888562296
# -6.17284001691587e-14
# -16.738615015131543
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: xlabel='x [m]', ylabel='Probability density [1 / m]'>)
